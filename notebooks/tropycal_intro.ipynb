# %%
from tropycal import realtime

# %%
realtime_obj = realtime.Realtime()
realtime_obj
# Out:
# --> Starting to read in current storm data
# --> Completed reading in current storm data (3.35 seconds)
# <tropycal.realtime.Realtime>
# Dataset Summary:
#     Numbers of active storms: 4
#     Time Updated: 1634 UTC 27 September 2022
#
# Active Storms:
#     AL092022
#
# Active Invests:
#     AL992022
#     EP152022
#     EP972022

# %%
realtime_obj
# Out:
# <tropycal.realtime.Realtime>
# Dataset Summary:
#     Numbers of active storms: 4
#     Time Updated: 1509 UTC 27 September 2022
#
# Active Storms:
#     AL092022
#
# Active Invests:
#     AL992022
#     EP152022
#     EP972022

# %%
dir(realtime_obj)
# Out:
# ['AL092022',
#  'AL992022',
#  'EP152022',
#  'EP972022',
#  '_Realtime__read_btk',
#  '_Realtime__read_btk_jtwc',
#  '_Realtime__read_nhc_shapefile',
#  '__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__setitem__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  'attrs',
#  'get_storm',
#  'jtwc',
#  'jtwc_source',
#  'list_active_storms',
#  'plot_summary',
#  'ssl_certificate',
#  'storms',
#  'time',
#  'update']

# %%
realtime_obj.plot_summary(domain={'w':-100,'e':-10,'s':4,'n':60})
# Out:
# Possible issue encountered when converting Shape #0 to GeoJSON: Shapefile format requires that polygons contain at least one exterior ring, but the Shape was entirely made up of interior holes (defined by counter-clockwise orientation in the shapefile format). The rings were still included but were encoded as GeoJSON exterior rings instead of holes.
# Possible issue encountered when converting Shape #0 to GeoJSON: Shapefile format requires that polygons contain at least one exterior ring, but the Shape was entirely made up of interior holes (defined by counter-clockwise orientation in the shapefile format). The rings were still included but were encoded as GeoJSON exterior rings instead of holes.
# ...

# %%
realtime_obj.storms
# Out:
# ['AL092022', 'AL992022', 'EP152022', 'EP972022']

# %%
dir(realtime_obj.AL092022)
# Out:
# ['_RealtimeStorm__get_ensembles_eps',
#  '_RealtimeStorm__get_public_advisory',
#  '__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__setitem__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  'ace',
#  'archer',
#  'attrs',
#  'basin',
#  'date',
#  'dict',
#  'download_graphic_realtime',
#  'download_tcr',
#  'extra_obs',
#  'get_archer',
#  'get_discussion_realtime',
#  'get_forecast_realtime',
#  'get_nhc_discussion',
#  'get_nhc_forecast_dict',
#  'get_operational_forecasts',
#  'get_realtime_formation_prob',
#  'get_realtime_info',
#  'get_recon',
#  'id',
#  'interp',
#  'invest',
#  'jtwc_source',
#  'lat',
#  'latest_forecast',
# ...

# %%
realtime_obj.AL092022
# Out:
# <tropycal.realtime.RealtimeStorm>
# Storm Summary:
#     Maximum Wind:      105 knots
#     Minimum Pressure:  951 hPa
#     Start Date:        0600 UTC 23 September 2022
#     End Date:          1800 UTC 27 September 2022
#
# Variables:
#     date        (datetime) [2022-09-19 12:00:00 .... 2022-09-27 18:00:00]
#     extra_obs   (int64) [0 .... 0]
#     special     (str) [ .... ]
#     type        (str) [DB .... HU]
#     lat         (float64) [9.9 .... 23.5]
#     lon         (float64) [-46.6 .... -83.3]
#     vmax        (int64) [20 .... 105]
#     mslp        (int64) [1012 .... 951]
#     wmo_basin   (str) [north_atlantic .... north_atlantic]
#
# More Information:
#     id:              AL092022
#     operational_id:  AL092022
#     name:            IAN
#     year:            2022
#     season:          2022
#     basin:           north_atlantic
#     source_info:     NHC Hurricane Database
#     invest:          False
# ...
